# %% [markdown]
# # 📈 Logistic Regresion
#
# <a href="https://colab.research.google.com/github/rubenfonnegra/machine_learning/blob/master/Sem_02/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <a href="https://github.com/rubenfonnegra/machine_learning/blob/master/Sem_02/Logistic_Regression.ipynb" target="_parent"><img src="https://img.shields.io/badge/%E2%80%8B-Open%20in%20Github-blue?logo=github" alt="Open In Github"/></a>
#
#
# ### Learning objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain logistic regression as a supervised classification algorithm.
# - Interpret predicted probabilities and classification thresholds.
# - Train binary and multiclass logistic regression models with scikit-learn.
#
#
# ### Documentation
#
# - [```scikit-learn```](https://scikit-learn.org/stable/index.html)
# - [```Iris```](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)
# - [```LogisticRegression``` ](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html?highlight=logistic%20regression#sklearn.linear_model.LogisticRegression)
#
#
# ---
#
# > **📘 Machine Learning**
# > **Author:** Rubén D. Fonnegra, Ph.D. \
# > **Institution:** Institución Universitaria Pascual Bravo
# > © 2026 · Educational use with attribution

# %% [markdown]
# ### In Synthetic data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = 500 , n_features = 2 , n_redundant = 0, n_informative = 2, n_clusters_per_class = 1, n_classes = 2, random_state = 8)

_, ax = plt.subplots(figsize=( 5 , 4 ))
ax.scatter( X[:, 0] , X[:, 1] , c = y , cmap = 'Paired', edgecolors="k")
ax.set_axis_off()

# %%
# Create an instance
logistic_regression = LogisticRegression()

# Train the model
logistic_regression.fit ( X , y ) #(# Samples, # Features)
# Out:
# LogisticRegression()

# %%
logistic_regression.coef_
# Out:
# array([[-2.05708959,  1.85247996]])

# %%
X[0,]
# Out:
# array([ 0.96003068, -1.02389333])

# %%
yn = (logistic_regression.coef_[0, 0] * X[0] + logistic_regression.coef_[0, 1] * X[0]) + logistic_regression.intercept_

# %%
print(yn.shape)
# Out:
# (2,)

# %% [markdown]
# ### Decision boundaries

# %%
# Min-Max values for the grid of decision boundaries
x_min, x_max = np.min(X[:, 0]) -.5 , np.max(X[:, 0]) +.5
y_min, y_max = np.min(X[:, 1]) -.5 , np.max(X[:, 1]) +.5

# Create grid
x_grid, y_grid = np.meshgrid( np.linspace(x_min, x_max, 200) , np.linspace(y_min, y_max, 200) )

# Estimate predictions over the grid
predictions = logistic_regression.predict(np.c_[x_grid.ravel(), y_grid.ravel()])
print (predictions.shape)
# Out:
# (40000,)

# %%
# Reshape predictions
predictions = predictions.reshape(x_grid.shape)

# Draw grid
_, ax = plt.subplots (figsize=(8,5))
ax.pcolormesh( x_grid , y_grid , predictions , cmap = "Paired")

# Scatter real values
ax.scatter ( X[:, 0] , X[:, 1] , c = y , edgecolors = 'k', cmap = "Paired")
# ax.scatter ( X[0], yn )

ax.set_xticks(())
ax.set_yticks(())
# Out:
# []

# %% [markdown]
# ### In Real data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris

# %%
iris = _ # Load iris dataset
iris_x = _ # Features
iris_y = _ # Labels

# Imprimir formas
print (iris_x.shape, iris_y.shape)

# %%
# Create an instance
decision_tree = LogisticRegression()

# Train the model
decision_tree.fit ( _ , _ ) #(# Samples, # Features)

# %%
# Min-Max values for the grid of decision boundaries
x_min, x_max = _ , _
y_min, y_max = _ , _

# Create grid
x_grid, y_grid = np.meshgrid( _ , _ )

# Estimate predictions over the grid
predictions = logistic_regression.predict(np.c_[x_grid.ravel(), y_grid.ravel()])
print (predictions.shape)

# %%
# Reshape predictions
predictions = _

# Draw grid
_, ax = plt.subplots (figsize=(8,5))
ax.pcolormesh( _ , _ , _ , cmap = "Paired")

# Scatter real values
ax.scatter ( _ , _ , c = _ , edgecolors = 'k', cmap = "Paired")

ax.set_xticks(())
ax.set_yticks(())

# %% [markdown]
# ---
#
# ## 📄 Attribution
#
# This notebook was developed by **Rubén D. Fonnegra** as educational material for Machine Learning courses at **Institución Universitaria Pascual Bravo**.
# You may use, share, and adapt this material for educational purposes, provided that appropriate credit is given to the original author.
#
# **Suggested citation:**
# > Fonnegra Tarazona, R. D. (2026). *Logistic Regression: Machine Learning Notebook*. Institución Universitaria Pascual Bravo.
