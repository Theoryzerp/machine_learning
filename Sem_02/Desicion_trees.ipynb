# %% [markdown]
# # 🌳 Decision Trees
#
# <a href="https://colab.research.google.com/github/rubenfonnegra/machine_learning/blob/master/Sem_02/Desicion_trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <a href="https://github.com/rubenfonnegra/machine_learning/blob/master/Sem_02/Desicion_trees.ipynb" target="_parent"><img src="https://img.shields.io/badge/%E2%80%8B-Open%20in%20Github-blue?logo=github" alt="Open In Github"/></a>
#
#
# ### Learning objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain how a decision tree makes predictions.
# - Understand root nodes, decision nodes, branches, and leaves.
# - Train a classification tree with `scikit-learn`.
# - Visualize and evaluate a trained tree.
#
# ### Documentation
#
# - [```scikit-learn```](https://scikit-learn.org/stable/index.html)
# - [```DecisionTreeClassifier```](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier)
#
# ---
#
# > **📘 Machine Learning**
# > **Author:** Rubén D. Fonnegra, Ph.D. \
# > **Institution:** Institución Universitaria Pascual Bravo
# > © 2026 · Educational use with attribution

# %% [markdown]
# ## Creating Synthetic data

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = 500 , n_features = 2 , n_redundant = 0, n_informative = 2, n_clusters_per_class = 1, n_classes = 2, random_state = 8)

_, ax = plt.subplots(figsize=( 5 , 4 ))
ax.scatter( X[:, 0] , X[:, 1] , c = y , edgecolors = "k", cmap = 'Paired')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# ## Splitting nodes in a decision tree?
#
# A classification tree tries to create groups that are as pure as possible.
#
# ### Gini impurity
#
# $$Gini = 1 - \sum_{i=1}^{k} p_i^2$$
#
# ### Entropy
#
# $$Entropy = -\sum_{i=1}^{k} p_i \log_2(p_i)$$
#
# Here, $p_i$ is the proportion of observations belonging to class $i$. Lower impurity means a more homogeneous node.

# %%
# Create an instance
decision_tree = DecisionTreeClassifier(criterion="gini", max_depth=10)

# Train the model
decision_tree.fit ( X, y ) #(# Samples, # Features)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %% [markdown]
# ## Visualizing the Decision Tree

# %%
_, ax = plt.subplots(figsize=(12,10))
plot_tree(decision_tree, filled=True, fontsize=5, ax=ax)
# Out:
# [Text(0.6599264705882353, 0.9545454545454546, 'x[0] <= 0.213\ngini = 0.5\nsamples = 500\nvalue = [248, 252]'),
#  Text(0.46691176470588236, 0.8636363636363636, 'x[0] <= -0.638\ngini = 0.29\nsamples = 279\nvalue = [49, 230]'),
#  Text(0.5634191176470589, 0.9090909090909092, 'True  '),
#  Text(0.3161764705882353, 0.7727272727272727, 'x[1] <= 1.026\ngini = 0.133\nsamples = 182\nvalue = [13, 169]'),
#  Text(0.19117647058823528, 0.6818181818181818, 'x[0] <= -0.719\ngini = 0.043\nsamples = 135\nvalue = [3, 132]'),
#  Text(0.11764705882352941, 0.5909090909090909, 'x[0] <= -0.9\ngini = 0.03\nsamples = 133\nvalue = [2, 131]'),
#  Text(0.058823529411764705, 0.5, 'x[0] <= -1.471\ngini = 0.016\nsamples = 125\nvalue = [1, 124]'),
#  Text(0.029411764705882353, 0.4090909090909091, 'gini = 0.0\nsamples = 67\nvalue = [0, 67]'),
#  Text(0.08823529411764706, 0.4090909090909091, 'x[0] <= -1.45\ngini = 0.034\nsamples = 58\nvalue = [1, 57]'),
#  Text(0.058823529411764705, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11764705882352941, 0.3181818181818182, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(0.17647058823529413, 0.5, 'x[0] <= -0.89\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.14705882352941177, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20588235294117646, 0.4090909090909091, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.2647058823529412, 0.5909090909090909, 'x[1] <= 0.738\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.23529411764705882, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29411764705882354, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4411764705882353, 0.6818181818181818, 'x[0] <= -0.944\ngini = 0.335\nsamples = 47\nvalue = [10, 37]'),
#  Text(0.38235294117647056, 0.5909090909090909, 'x[1] <= 1.471\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.35294117647058826, 0.5, 'x[1] <= 1.058\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.3235294117647059, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.38235294117647056, 0.4090909090909091, 'x[0] <= -1.358\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.35294117647058826, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4117647058823529, 0.3181818181818182, 'x[0] <= -1.153\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.35294117647058826, 0.22727272727272727, 'x[0] <= -1.185\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3235294117647059, 0.13636363636363635, 'x[0] <= -1.277\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.29411764705882354, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35294117647058826, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38235294117647056, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.47058823529411764, 0.22727272727272727, 'x[0] <= -1.074\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4411764705882353, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.13636363636363635, 'x[0] <= -1.024\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.47058823529411764, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5294117647058824, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4117647058823529, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5, 0.5909090909090909, 'x[0] <= -0.893\ngini = 0.064\nsamples = 30\nvalue = [1, 29]'),
#  Text(0.47058823529411764, 0.5, 'x[1] <= 1.168\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4411764705882353, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.4090909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5294117647058824, 0.5, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.6176470588235294, 0.7727272727272727, 'x[1] <= 1.091\ngini = 0.467\nsamples = 97\nvalue = [36, 61]'),
#  Text(0.5882352941176471, 0.6818181818181818, 'x[1] <= 0.889\ngini = 0.053\nsamples = 37\nvalue = [36, 1]'),
#  Text(0.5588235294117647, 0.5909090909090909, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(0.6176470588235294, 0.5909090909090909, 'x[0] <= -0.556\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5882352941176471, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6470588235294118, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6470588235294118, 0.6818181818181818, 'gini = 0.0\nsamples = 60\nvalue = [0, 60]'),
#  Text(0.8529411764705882, 0.8636363636363636, 'x[1] <= 1.099\ngini = 0.179\nsamples = 221\nvalue = [199, 22]'),
#  Text(0.7564338235294117, 0.9090909090909092, '  False'),
#  Text(0.8235294117647058, 0.7727272727272727, 'x[1] <= -0.827\ngini = 0.029\nsamples = 202\nvalue = [199, 3]'),
#  Text(0.7647058823529411, 0.6818181818181818, 'x[1] <= -1.598\ngini = 0.014\nsamples = 140\nvalue = [139, 1]'),
#  Text(0.7352941176470589, 0.5909090909090909, 'x[1] <= -1.602\ngini = 0.029\nsamples = 68\nvalue = [67, 1]'),
#  Text(0.7058823529411765, 0.5, 'gini = 0.0\nsamples = 67\nvalue = [67, 0]'),
#  Text(0.7647058823529411, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7941176470588235, 0.5909090909090909, 'gini = 0.0\nsamples = 72\nvalue = [72, 0]'),
#  Text(0.8823529411764706, 0.6818181818181818, 'x[1] <= -0.826\ngini = 0.062\nsamples = 62\nvalue = [60, 2]'),
#  Text(0.8529411764705882, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9117647058823529, 0.5909090909090909, 'x[0] <= 0.822\ngini = 0.032\nsamples = 61\nvalue = [60, 1]'),
#  Text(0.8823529411764706, 0.5, 'gini = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.9411764705882353, 0.5, 'x[0] <= 0.829\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.9117647058823529, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9705882352941176, 0.4090909090909091, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8823529411764706, 0.7727272727272727, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]')]

# %% [markdown]
# ### How to read a node
#
# - **Condition**: the question used to split the data.
# - **gini**: node impurity.
# - **samples**: training observations in the node.
# - **value**: observations from each class.
# - **class**: predicted class.

# %% [markdown]
# ## Load the Iris Classification Dataset
#
# The [Iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris) contains measurements for three flower species: Setosa, Versicolor, and Virginica.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import load_iris

# %%
iris = _ # Load iris dataset
iris_X = _ # Features
iris_y = _ # Labels

# Imprimir formas
print (iris_X.shape, iris_y.shape)

# %%
# Create an instance
decision_tree = DecisionTreeClassifier(criterion= "gini", max_depth=)

# Train the model
decision_tree.fit ( _ , _ ) #(# Samples, # Features)
# Out:
#   Cell In[10], line 2
#     decision_tree = DecisionTreeClassifier(criterion= "gini", max)
#                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
_, ax = plt.subplots(figsize=( _ , _ ))
plot_tree(decision_tree, filled=True, fontsize=5, ax=ax)

# %% [markdown]
# ## Advantages and Limitations
#
# ### Advantages
#
# - Easy to understand and visualize.
# - Requires little data preparation.
# - Handles nonlinear relationships.
# - Works for classification and regression.
# - Can model feature interactions.
#
# ### Limitations
#
# - Can overfit easily.
# - Small data changes may produce a different tree.
# - Greedy splits do not guarantee the globally best tree.
# - Deep trees may become difficult to interpret.
# - Feature importance can be misleading when features are correlated.

# %% [markdown]
# ## Practice Exercises
#
# ### Exercise 1: Change the criterion
#
# Train a classifier using `criterion="entropy"` and compare its test accuracy with the Gini-based model.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2: Limit the tree
#
# Train trees with `max_depth=2`, `max_depth=4`, and `max_depth=None`. Compare training accuracy, testing accuracy, and number of leaves.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: New prediction
#
# Create a new flower measurement and predict its class and class probabilities.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## 📄 Attribution
#
# This notebook was developed by **Rubén D. Fonnegra** as educational material for Machine Learning courses at **Institución Universitaria Pascual Bravo**.
# You may use, share, and adapt this material for educational purposes, provided that appropriate credit is given to the original author.
#
# **Suggested citation:**
# > Fonnegra Tarazona, R. D. (2026). *Decision Trees: Machine Learning Notebook*. Institución Universitaria Pascual Bravo.
